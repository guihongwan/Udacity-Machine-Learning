# %% [markdown]
# From http://onlinestatbook.com/2/describing_bivariate_data/pearson.html
#
# Learning Objectives
# - Describe what Pearson's correlation measures
# - Give the symbols for Pearson's correlation in the sample and in the population
# - State the poosible range for Pearson's correlation
# - Identify a perfect linear relationship

# %%
# The Pearson product-moment correlation coefficient is a measure of the strength of the linear relationship
# between two variables.

#It is referred to as Pearson's correlation or simply as correlation coefficient.

# If the relationship between the variables is not linear, then correlation coefficient does not adequately represent
# the strength of the relationship between the variables.

# %%
#The symbol for Pearson's correlation is 'ρ' when it is measured in the population
# and 'r' when it is measured in a sample.
# Because we will be dealing almost exclusively with samples, we will use r to represent Pearson's correlation.

# %%
# Pearson's r can range from -1 to 1.
# An r of -1 indicates a perfect negative linear relationship between variables;
# An r of 0 indicates no linear relationship between variables;
# An r of 1 indicates a perfect positive linear relationship between variables

# %%
from IPython.display import Image

# %%
#Figure 1 shows a scatter plot for which r = 1

Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/r1.jpg")

# %%
#Figure 2 shows a scatter plot for which r = -1
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/r2.jpg")

# %%
#Figure 3 A scatter plot for which r = 0.
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/r3.jpg")

# %%
#Figure 4 r of 0.97
# With real data, you would not expect to get values of r of exactly -1, 0, or 1.
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/age_scatterplot.jpg")

# %%
#Figure 5. r = 0.63
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/strength.jpg")
