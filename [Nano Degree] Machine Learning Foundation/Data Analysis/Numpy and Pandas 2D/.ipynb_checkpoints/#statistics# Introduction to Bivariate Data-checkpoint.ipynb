# %% [markdown]
# From  http://onlinestatbook.com/2/describing_bivariate_data/intro.html
# Learning Objectives
# - Define 'bivariate data'
# - Define 'scatter plot'
# - Distinguish between a linear and a nonliear relationship
# - Identify positive and negative associations from a scatter plot

# %% [markdown]
# quantitative variable:
# variables that are measured on a numeric or quantitative scale.
# Oridinal, interval and ratio scales are quantitative.
# Variables that are not quantitative are known as qualitative variables.

# %% [markdown]
# bivariate data:
#     consists of two quantitative variables for each individual.

# %% [markdown]
# Tabel1. Sample of spousal ages of 10 white American Couples
# Husband	36	72	37	36	51	50	47	50	37	41
# Wife	35	67	33	35	50	46	47	42	36	41

# %%
# Figure 2 : scatter plot of paired ages
# The x-axis represents the age of husband
# The y-axis represents the age of the wife

# %%
from IPython.display import Image
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/age_scatterplot.jpg")

# %%
# There are two important characteristics of the data revealed by Figure2.
# 1. the older the husband, the older the wife
# When one variable(Y) increases with the second variable(X), -> X and Y have a positive association
# Conversely, when Y decreases as X increases, we say that we have a negative association.
# 2. the points cluster along a straight line. When this occurs, the relationship is called a linear relationship.

# %%
# Figure 3 Galieo's data showing a non-linear relationship

# %%
Image("http://onlinestatbook.com/2/describing_bivariate_data/graphics/galileo.jpg")

# %%
# Scatter plots that show linear relationships between variables can differ in several ways including the slope of the line, how tightly the points cluster about the line.
# a statistical measure of the strength of the relationship between two quantitative variables that
# takes these factors into accounts is the subject of the section 'Values of Pearson's Correlation.'.
